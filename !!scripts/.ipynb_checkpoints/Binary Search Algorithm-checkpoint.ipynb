# %%
def binary_search(alist, item):
    print("\nThere are " + str(len(alist)) + " items in the list.")
    first = 0
    last = len(alist)-1
    found = False
    attempt = 0
    while first<=last and not found:
        attempt = attempt + 1
        print("Attempt # " + str(attempt))
        midpoint = (first + last)//2
        print("Trying the number " + str(alist[midpoint]))
        if alist[midpoint] == item:
            found = True
            print("\nIt took " + str(attempt) + " tries to determine that the " +
                  "number we're looking for, [" + str(item) + 
                  "], was at Python index position number " + 
                  str(midpoint) + " from the list of " + 
                  str(len(alist)) + " numbers.")
        else:
            if item < alist[midpoint]:
                last = midpoint-1
            else:
                first = midpoint+1
    if found == False:
        print("The number we're looking for, [" + str(item) + 
                 "], is not in the list.")
    return print("\n", found)
	 
def binary_search_reverse(alist, item):
    print("\nThere are " + str(len(alist)) + " items in the list.")
    first = len(alist)-1
    last = 0
    found = False
    attempt = 0
    while last<=first and not found:
        attempt = attempt + 1
        print("Attempt # " + str(attempt))
        midpoint = (first + last)//2
        print("Trying the number " + str(alist[midpoint]))
        if alist[midpoint] == item:
            found = True
            print("\nIt took " + str(attempt) + " tries to determine that the " +
                  "number we're looking for, [" + str(item) + 
                  "], was at Python index position number " + 
                  str(midpoint) + " from the list of " + 
                  str(len(alist)) + " numbers.")
        else:
            if item < alist[midpoint]:
                last = midpoint-1
            else:
                first = midpoint+1
    if found == False:
        print("The number we're looking for, [" + str(item) + 
                 "], is not in the list.")
    return print("\n", found)

#my_list = [0, 1, 2, 5, 8, 10, 13, 17, 19, 24, 27, 32, 39, 41, 44, 47, 49, 52, 
#           55, 57, 59, 63, 65, 68, 70, 74, 77, 79, 83, 85, 87, 90, 92, 93, 94, 
#           95, 96, 97, 98, 99]
my_list = list(range(0, 101))
my_list2 = sorted(my_list, reverse=True)
#print("\nThe number is at index " + str(binary_search(my_list, 3)))
#print()
#print("\n", binary_search(my_list, 5))

print(binary_search(my_list, 59))
print(binary_search_reverse(my_list2, 41))
# Out:
# There are 101 items in the list.
# Attempt # 1
# Trying the number 50
# Attempt # 2
# Trying the number 75
# Attempt # 3
# Trying the number 62
# Attempt # 4
# Trying the number 56
# Attempt # 5
# Trying the number 59
#
# It took 5 tries to determine that the number we're looking for, [59], was at Python index position number 59 from the list of 101 numbers.
#
#  True
# None
#
# There are 101 items in the list.
# Attempt # 1
# Trying the number 50
# Attempt # 2
# Trying the number 26
# Attempt # 3
# Trying the number 38
# Attempt # 4
# Trying the number 44
# Attempt # 5
# Trying the number 41
#
# It took 5 tries to determine that the number we're looking for, [41], was at Python index position number 59 from the list of 101 numbers.
#
#  True
# None

# %%
print(binary_search(list(range(0, 10000000)), 150276))
# Out:
# There are 10000000 items in the list.
# Attempt # 1
# Trying the number 4999999
# Attempt # 2
# Trying the number 2499999
# Attempt # 3
# Trying the number 1249999
# Attempt # 4
# Trying the number 624999
# Attempt # 5
# Trying the number 312499
# Attempt # 6
# Trying the number 156249
# Attempt # 7
# Trying the number 78124
# Attempt # 8
# Trying the number 117186
# Attempt # 9
# Trying the number 136717
# Attempt # 10
# Trying the number 146483
# Attempt # 11
# Trying the number 151366
# Attempt # 12
# Trying the number 148924
# Attempt # 13
# Trying the number 150145
# Attempt # 14
# Trying the number 150755
# Attempt # 15
# Trying the number 150450
# Attempt # 16
# Trying the number 150297
# Attempt # 17
# Trying the number 150221
# Attempt # 18
# Trying the number 150259
# Attempt # 19
# Trying the number 150278
# Attempt # 20
# Trying the number 150268
# Attempt # 21
# Trying the number 150273
# Attempt # 22
# Trying the number 150275
# Attempt # 23
# Trying the number 150276
#
# It took 23 tries to determine that the number we're looking for, [150276], was at Python index position number 150276 from the list of 10000000 numbers.
#
#  True
# None
