# %% [markdown]
# ## Directions: The dataset UN_cities_data.csv, provided by The Guardian newspaper, which contains data on the population of some of the world's largest cities, starting in 1950 and going through projections for 2025. Take the data, and try to apply what you learned to discover something interesting! Some ideas include: average city growth from year to year; which decade saw the fastest or slowest growth rates in a certain country, or worldwide; or anything else that you find interesting. Your project needs to involve loading the data into Python, running some analysis on it, and producing at least one visualization of your results. Good luck, and have fun!

# %%
# Import python packages
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read in cities data
cities = pd.read_csv("UN_cities_data.csv", sep='\t')

# %%
cities.head()
# Out:
#    Country code      Country  City Code    Urban Agglomeration  Latitude  \
# 0             4  Afghanistan      20002                  Kabul     34.54
# 1            12      Algeria      20006  El Djazaïr  (Algiers)     36.76
# 2            12      Algeria      20035          Wahran (Oran)     35.75
# 3            24       Angola      20050                 Huambo    -12.76
# 4            24       Angola      20049                 Luanda     -8.84
#
#    Longitude     1950     1955     1960      1965      ...           2010  \
# 0      69.17  128.931  184.622  264.803   368.809      ...       3052.000
# 1       3.05  516.450  622.921  871.636  1081.394      ...       2850.907
# 2      -0.63  268.935  286.368  304.936   324.697      ...        775.666
# 3      15.75   15.306   23.818   37.069    47.875      ...       1038.581
# 4      13.23  138.413  174.268  219.427   315.108      ...       4790.142
#
#        2015      2020      2025  Cyclone risk (0=low, 3=high)  Drought risk  \
# 0  3402.137  4135.559  5125.916                             0             3
# 1  3202.959  3607.835  3976.732                             0             2
# 2   825.859   920.440  1025.705                             0             3
# 3  1345.176  1665.779  1996.751                             0             3
# 4  6183.162  7555.184  8924.042                             0             3
#
#    Earthquake risk  Flood risk  Landslide risk  Volcano risk
# 0                1           3               0             0
# 1                1           2               0             0
# 2                0           1               0             0
# 3                0           0               0             0
# 4                0           1               0             0
#
# [5 rows x 28 columns]

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 28 columns):
# Country code                    633 non-null int64
# Country                         633 non-null object
# City Code                       633 non-null int64
# Urban Agglomeration             633 non-null object
# Latitude                        633 non-null float64
# Longitude                       633 non-null float64
# 1950                            633 non-null float64
# 1955                            633 non-null float64
# 1960                            633 non-null float64
# 1965                            633 non-null float64
# 1970                            633 non-null float64
# 1975                            633 non-null float64
# 1980                            633 non-null float64
# 1985                            633 non-null float64
# 1990                            633 non-null float64
# 1995                            633 non-null float64
# 2000                            633 non-null float64
# 2005                            633 non-null float64
# 2010                            633 non-null float64
# 2015                            633 non-null float64
# 2020                            633 non-null float64
# 2025                            633 non-null float64
# Cyclone risk (0=low, 3=high)    633 non-null int64
# Drought risk                    633 non-null int64
# Earthquake risk                 633 non-null int64
# Flood risk                      633 non-null int64
# Landslide risk                  633 non-null int64
# Volcano risk                    633 non-null int64
# dtypes: float64(18), int64(8), object(2)
# memory usage: 138.5+ KB

# %%
# Compute annual population growth for years with real data.
cities["Average_Annual_Growth_Rate"] = (cities["2010"] - cities["1950"])/(2010-1950)
cities.head()
# Out:
#    Country code      Country  City Code    Urban Agglomeration  Latitude  \
# 0             4  Afghanistan      20002                  Kabul     34.54
# 1            12      Algeria      20006  El Djazaïr  (Algiers)     36.76
# 2            12      Algeria      20035          Wahran (Oran)     35.75
# 3            24       Angola      20050                 Huambo    -12.76
# 4            24       Angola      20049                 Luanda     -8.84
#
#    Longitude     1950     1955     1960      1965             ...              \
# 0      69.17  128.931  184.622  264.803   368.809             ...
# 1       3.05  516.450  622.921  871.636  1081.394             ...
# 2      -0.63  268.935  286.368  304.936   324.697             ...
# 3      15.75   15.306   23.818   37.069    47.875             ...
# 4      13.23  138.413  174.268  219.427   315.108             ...
#
#        2015      2020      2025  Cyclone risk (0=low, 3=high)  Drought risk  \
# 0  3402.137  4135.559  5125.916                             0             3
# 1  3202.959  3607.835  3976.732                             0             2
# 2   825.859   920.440  1025.705                             0             3
# 3  1345.176  1665.779  1996.751                             0             3
# 4  6183.162  7555.184  8924.042                             0             3
#
#    Earthquake risk  Flood risk  Landslide risk  Volcano risk  \
# 0                1           3               0             0
# 1                1           2               0             0
# 2                0           1               0             0
# 3                0           0               0             0
# 4                0           1               0             0
#
#    Average_Annual_Growth_Rate
# 0                   48.717817
# 1                   38.907617
# 2                    8.445517
# 3                   17.054583
# 4                   77.528817
#
# [5 rows x 29 columns]

# %%
# Create data series for plotting
x_Longitude = cities.Longitude
y_Latitude  = cities.Latitude
population_growth = cities["Average_Annual_Growth_Rate"]

# %%
fig=plt.figure(figsize=(12,10))
ax=fig.add_subplot(111)
ax.scatter(x_Longitude,y_Latitude,s=population_growth, c="purple")
# Out:
# C:\Users\jenkij\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
pop_stat = cities.groupby([(cities["Average_Annual_Growth_Rate"]), (cities.Longitude),
                          (cities.Latitude)]).max()

# %%
pop_stat.iloc[-10:, :4]
# Out:
#                                                Country code     Country  \
# Average_Annual_Growth_Rate Longitude Latitude
# 174.384700                  3.40      6.45              566     Nigeria
# 207.405367                  67.05     24.87             586    Pakistan
# 222.136483                  116.43    39.92             156       China
# 243.231450                  90.41     23.72              50  Bangladesh
# 254.218617                  121.47    31.23             156       China
# 276.077067                  72.85     18.93             356       India
# 287.651767                 -99.12     19.50             484      Mexico
# 288.588800                 -46.62    -23.53              76      Brazil
# 342.762883                  77.22     28.67             356       India
# 427.635650                  139.75    35.69             392       Japan
#
#                                                City Code  \
# Average_Annual_Growth_Rate Longitude Latitude
# 174.384700                  3.40      6.45         22007
# 207.405367                  67.05     24.87        22044
# 222.136483                  116.43    39.92        20464
# 243.231450                  90.41     23.72        20119
# 254.218617                  121.47    31.23        20656
# 276.077067                  72.85     18.93        21206
# 287.651767                 -99.12     19.50        21853
# 288.588800                 -46.62    -23.53        20287
# 342.762883                  77.22     28.67        21228
# 427.635650                  139.75    35.69        21671
#
#                                                           Urban Agglomeration
# Average_Annual_Growth_Rate Longitude Latitude
# 174.384700                  3.40      6.45                              Lagos
# 207.405367                  67.05     24.87                           Karachi
# 222.136483                  116.43    39.92                           Beijing
# 243.231450                  90.41     23.72                             Dhaka
# 254.218617                  121.47    31.23                          Shanghai
# 276.077067                  72.85     18.93                   Mumbai (Bombay)
# 287.651767                 -99.12     19.50    Ciudad de México (Mexico City)
# 288.588800                 -46.62    -23.53                         São Paulo
# 342.762883                  77.22     28.67                             Delhi
# 427.635650                  139.75    35.69                             Tokyo

# %%
print("The data and the plot show the largest average annual growth rates in Japan and India.")
# Out:
# The data and the plot show the largest average annual growth rates in Japan and India.
