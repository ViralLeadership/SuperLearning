# %% [markdown]
# # Assignment 4
#
# ### (12 Marks)
#
# If you have not already done so, download the following csv file:
#
# * [tips.csv](https://www.dropbox.com/s/br6p2brp54cjpla/tips.csv?dl=1)
#
# Using the tips.csv file, pandas and matplotlib (pyplot), complete the following exercises:
#
# (assume total_bill is the cost of the meal without the tip and assume the values are in US dollars)
#
# * Show the file info
# * Display the first 5 rows of the file
# * Display the last 5 rows of the file
# * Display the minimum and maximum tips
# * Display the minimum and maximum meal cost
# * Display the average tip
# * Display the average meal cost
# * Create a new column that displays the total cost (total_cost) of each meal (total_bill + tip) and find the average total_cost of the meals
# * On average, who tips more in this data set, males or females?
#
# With matplotlib, display the following graphs
#
# * Display a scatterplot of total_bill (x-axis) vs. tip (y-axis), label the axes and add a title
# * Display a box plot of the tips
# * Display a histogram of female tip amounts, label the x-axis
# * Display a histogram of male tip amounts, label the x-axis

# %%
"""
Using the tips.csv file, pandas and matplotlib (pyplot), complete the
following exercises:
(assume total_bill is the cost of the meal without the tip and assume
the values are in US dollars)
"""

# import pandas for data analysis and matplotlib for plotting
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("tips.csv")

#Show the file info
print("The file info for data is as follows: \n") 
data.info()

#Display the first 5 rows of the file
print("\nThe first 5 rows of the file are: \n\n", data.head())

#Display the last 5 rows of the file
print("\nThe last 5 rows of the file are: \n\n", data.tail())

#Display the minimum and maximum tips
print("\nThe minimum tip was $" + str(data["tip"].min()) + ".")
print("The maximum tip was $" + str(data["tip"].max()) + ".\n")

#Display the minimum and maximum meal cost
print("\nThe minimum meal cost was $" + str(data["total_bill"].min()) + ".")
print("The maximum meal cost was $" + str(data["total_bill"].max()) + ".\n")

#Display the average tip
print("The average tip was " + str(data["tip"].mean()) + ".\n")

#Display the average meal cost
print("The average meal cost was " + str(data["total_bill"].mean()) + ".\n")

#Create a new column that displays the total cost (total_cost) of each meal (total_bill + tip) and find the average total_cost of the meals
data["total_cost"] = data["total_bill"] + data["tip"]
print("With the new column showing total cost, the first 5 rows " + 
      "of the file are: \n", data.head())

#On average, who tips more in this data set, males or females?
#data[data.sex = "Female"]
females = data[data.sex == "Female"]
males = data[data.sex == "Male"]
print("\nIn this data set the average female tip is $",
      females["tip"].mean())
print("In this data set the average male tip is $",
      males["tip"].mean())
if females["tip"].mean() > males["tip"].mean():
    print("\nOn average in this data set females tip more than males.")
else:
    print("\nOn average, in this data set, males tip more than females.")
# Out:
# The file info for data is as follows:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB
#
# The first 5 rows of the file are:
#
#     total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# The last 5 rows of the file are:
#
#       total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# The minimum tip was $1.0.
# The maximum tip was $10.0.
#
#
# The minimum meal cost was $3.07.
# The maximum meal cost was $50.81.
#
# The average tip was 2.9982786885245902.
#
# The average meal cost was 19.785942622950824.
#
# With the new column showing total cost, the first 5 rows of the file are:
#     total_bill   tip     sex smoker  day    time  size  total_cost
# 0       16.99  1.01  Female     No  Sun  Dinner     2       18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3       12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3       24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2       26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4       28.20
#
# In this data set the average female tip is $ 2.833448275862069
# In this data set the average male tip is $ 3.0896178343949052
#
# On average, in this data set, males tip more than females.

# %%
#With matplotlib, display the following graphs
#Display a scatterplot of total_bill (x-axis) vs. tip (y-axis), label the axes and add a title
x = data["total_bill"]
y = data["tip"]

# axis labels and graph title
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter Plot: "Total Bill vs. Tip"')

# render the scatter plot
plt.scatter(x,y)
plt.show()

#Display a box plot of the tips
plt.boxplot(data['tip'])
plt.show()

#Display a histogram of female tip amounts, label the x-axis
females = data[data.sex == "Female"]
plt.hist(females["tip"])
plt.xlabel('Female Tip Amounts')
plt.show()

#Display a histogram of male tip amounts, label the x-axis
males = data[data.sex == "Male"]
plt.hist(males["tip"])
plt.xlabel('Male Tip Amounts')
plt.show()

# %% [markdown]
# Go to the matplotlib website and copy the code from an example plot... any example plot that looks interesting or pleasing to you.  There is no other requirement for this exercise.
#
# Paste the code in the cell below and display the graph.  Yes, this is easy and somewhat trivial... but I want to be dazzled by something neat  :-)

# %%
"""
==========================
Scatter plot on polar axis
==========================

Demo of scatter plot on a polar axis.

Size increases radially in this example and color increases with angle
(just to verify the symbols are being scattered correctly).
"""
import numpy as np
import matplotlib.pyplot as plt


# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

ax = plt.subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

plt.show()
